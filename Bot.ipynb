# %% [markdown]
# <a href="https://colab.research.google.com/github/Brian342/AI/blob/main/Bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries and packages
import numpy as np
import time
import os
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
# checkpoint
checkpoint = "microsoft/DialoGpt-medium"
# download cache tokenezer
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = AutoModelForCausalLM.from_pretrained(checkpoint)
# Out:
# pytorch_model.bin:   0%|          | 0.00/863M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
# chatbot class
class chatbot():
    def __init__(self):
        # history saved for chat continuty
        self.chat_history_ids = None
        # make input ids global to use them anywhere
        self.bot_input_ids = None
        # check whether to end the conversation
        self.end_chat =False
        # greet while starting
        self.welcome()

        # welcome message
    def  welcome(self):
        print("Starting chatbot.....")
        time.sleep(2)
        print("Type 'bye' or 'quit' or 'exit' to end chat \n")
        time.sleep(3)

        greetings = np.random.choice([
            "Welcome, I am DroidBot, here for your kind service",
            "Hey, Great day! I am your virtual assistant",
            "Hello, pleasure meeting you",
            "Hi, I am a DroidBot. Let's chat!"
        ])
        print(f"DroidBot >>  {greetings}" )

    def user_input(self):
        text = input("User >>")
        if  text.lower().strip() in ['bye', 'quit', 'exit']:
            self.end_chat = True
            print("See you soon Bye")
            time.sleep(1)
            print("\n Qutting DroidBot")
        else:
            self.new_user_input_ids = tokenizer.encode(text + tokenizer.eos_token, return_tensor = "pt")
